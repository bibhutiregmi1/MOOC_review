# %%
import pandas as pd

# %%
df = pd.read_csv('feedback_week1.csv').iloc[:,0:4]

# %%
df.isnull().sum()
# Out:
# User full name    0
# Email address     0
# Date              0
# Feedback          0
# dtype: int64

# %%
n=dataset.shape[0]

# %%
import nltk

# %%
reviews=dataset['Feedback']

# %%
df['reviews.text'] =df['Feedback'].astype(str)

# %% [markdown]
# ### Data Cleanup process

# %%
#lower case
df['reviews.text'] = df['reviews.text'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
## remove punctuation
df['reviews.text'] = df['reviews.text'].str.replace('[^\w\s]','')

# %%
## remove stopwords

from nltk.corpus import stopwords
stop = stopwords.words('english')
df['reviews.text'] = df['reviews.text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %%
#special character
df['reviews.text'] = df['reviews.text'].str.replace('[^\w\s]','')

# %%
## regular expression cleanup
import re

REPLACE_NO_SPACE = re.compile("[.;:!\'?,\"()\[\]]")
REPLACE_WITH_SPACE = re.compile("(<br\s*/><br\s*/>)|(\-)|(\/)")
DIGIT_REMOVE = re.compile(r"(^|\W)\d+")
NEW_LINE_REMOVE = re.compile("\n")


def preprocess_reviews(reviews):
    reviews = [REPLACE_NO_SPACE.sub("", line.lower()) for line in reviews]
    reviews = [REPLACE_WITH_SPACE.sub(" ", line) for line in reviews]
    reviews = [DIGIT_REMOVE.sub("", line) for line in reviews]
    reviews = [NEW_LINE_REMOVE.sub("", line) for line in reviews]
    
    return reviews

df['reviews.text'] = preprocess_reviews(df['reviews.text'])

# %%
#### Lemmatization

# %%
def get_lemmatized_text(corpus):
    from nltk.stem import WordNetLemmatizer
    lemmatizer = WordNetLemmatizer()
    return [' '.join([lemmatizer.lemmatize(word) for word in review.split()]) for review in corpus]

df['reviews.text'] = get_lemmatized_text(df['reviews.text'])

# %%
### stemming

# %%
# st = PorterStemmer()
# df['reviews.text'] = df['reviews.text'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))

# %% [markdown]
# ### Frequently used words

# %%
most = pd.Series(' '.join(df['reviews.text']).split()).value_counts()[:10]
most
# Out:
# week           47
# content        46
# hci            36
# learning       28
# course         28
# interesting    26
# system         25
# video          23
# really         21
# good           21
# dtype: int64

# %% [markdown]
# ### Word cloud

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)

# %%
def show_wordcloud(col, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=500,
        max_font_size=40, 
        scale=3,
        random_state=1
    ).generate(str(col))

    fig = plt.figure(1, figsize=(10, 10))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=10)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()


if __name__ == '__main__':
    show_wordcloud(df['reviews.text'])
#     show_wordcloud(df['review'])

# %% [markdown]
# ## Adjectives used

# %%
feelings = []
for sentence in df['reviews.text']:
    # each sentence is either a list of words or a list of (word, POS tag) tuples
    for word, pos in nltk.pos_tag(sentence.split()): # remove the call to nltk.pos_tag if `sentence` is a list of tuples as described above
        if pos in ['JJR', "JJ", "JJS", "RB","RBR","RBS"]: # feel free to add any other noun tags
            feelings.append(word)

# %%
most = pd.Series(' '.join(feelings).split()).value_counts()[:10]
most
# Out:
# really         21
# also           19
# good           18
# first          17
# content        15
# well           12
# interesting    11
# helpful        10
# new             9
# different       9
# dtype: int64

# %% [markdown]
# ### Sentiment scoring

# %%
def senti(x):
    return TextBlob(x).sentiment  
 
df['senti_score'] = df['reviews.text'].apply(senti)
 
df.senti_score.head()
# Out:
# 0                                    (0.4, 0.4)
# 1      (0.3954545454545455, 0.5126262626262627)
# 2      (0.4642857142857143, 0.5476190476190476)
# 3                                 (0.375, 0.55)
# 4    (0.16666666666666669, 0.41666666666666663)
# Name: senti_score, dtype: object

# %%
import pandas as pd
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#load in the sentiment analyzer
sia=SentimentIntensityAnalyzer()

#apply the analyzer over each comment
df['polairty scores'] =df['reviews.text'].apply(lambda x: sia.polarity_scores(x)['compound'])
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/bibhuti/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
def sentiment(score):
    if score<0 :
        return "Negative"
    elif score<=0.5:
        return "Neutral"
    elif score>0.5:
        return "Positive"

# %%
sentiment_list=[]
for a in df['polairty scores']:
    sentiment_list.append(sentiment(a))
df['Sentiment']=sentiment_list

# %%
df['Sentiment'].value_counts().plot(kind="pie")
plt.show()

# %%
df.to_csv('review_analysis.csv',index=False)
